# %%
# Import & Install Dependencies
# !pip install tensorflow tensorflow-gpu tensorflow-io matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\jasmi\anaconda3\lib\site-packages (2.11.0)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
# Requirement already satisfied: tensorflow-io in c:\users\jasmi\anaconda3\lib\site-packages (0.31.0)
# Requirement already satisfied: matplotlib in c:\users\jasmi\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (58.0.4)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: numpy>=1.20 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: packaging in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.3)
# Requirement already satisfied: python_version>"3.7" in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow-gpu) (0.0.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jasmi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jasmi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jasmi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jasmi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\jasmi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jasmi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jasmi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jasmi\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jasmi\\AppData\\Local\\Temp\\pip-install-mg8o_p2m\\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\\setup.py'"'"'; __file__='"'"'C:\\Users\\jasmi\\AppData\\Local\\Temp\\pip-install-mg8o_p2m\\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jasmi\AppData\Local\Temp\pip-wheel-tl00gl1k'
#        cwd: C:\Users\jasmi\AppData\Local\Temp\pip-install-mg8o_p2m\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\
#   Complete output (17 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\jasmi\AppData\Local\Temp\pip-install-mg8o_p2m\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   ----------------------------------------
#   ERROR: Failed building wheel for tensorflow-gpu
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jasmi\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jasmi\\AppData\\Local\\Temp\\pip-install-mg8o_p2m\\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\\setup.py'"'"'; __file__='"'"'C:\\Users\\jasmi\\AppData\\Local\\Temp\\pip-install-mg8o_p2m\\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jasmi\AppData\Local\Temp\pip-record-dhaok33m\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jasmi\anaconda3\Include\tensorflow-gpu'
#          cwd: C:\Users\jasmi\AppData\Local\Temp\pip-install-mg8o_p2m\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\
#     Complete output (17 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\jasmi\AppData\Local\Temp\pip-install-mg8o_p2m\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\setup.py", line 37, in <module>
#         raise Exception(TF_REMOVAL_WARNING)
#     Exception:
#
#     =========================================================
#     The "tensorflow-gpu" package has been removed!
#
#     Please install "tensorflow" instead.
#
#     Other than the name, the two packages have been identical
#     since TensorFlow 2.1, or roughly since Sep 2019. For more
#     information, see: pypi.org/project/tensorflow-gpu
#     =========================================================
#
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\jasmi\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jasmi\\AppData\\Local\\Temp\\pip-install-mg8o_p2m\\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\\setup.py'"'"'; __file__='"'"'C:\\Users\\jasmi\\AppData\\Local\\Temp\\pip-install-mg8o_p2m\\tensorflow-gpu_8b555115ac0c4f089d2b4c4fa1810810\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jasmi\AppData\Local\Temp\pip-record-dhaok33m\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jasmi\anaconda3\Include\tensorflow-gpu' Check the logs for full command output.
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: tensorflow-gpu
#     Running setup.py install for tensorflow-gpu: started
#     Running setup.py install for tensorflow-gpu: finished with status 'error'

# %%
# Load dependencies!
import os
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio

# %% [markdown]
# Data Loading Function!

# %%
# Defining paths!
Asthma_File = os.path.join('Data','Archive_2','Asthma','103_2b2_Ar_mc_LittC2SE.wav')
Bronchiectasis_File = os.path.join('Data','Archive_2','Bronchiectasis','111_1b2_Tc_sc_Meditron.wav')
Bronchiolitis_File = os.path.join('Data','Archive_2','Bronchiolitis','149_1b1_Al_sc_Meditron.wav')
COPD_File = os.path.join('Data','Archive_2','COPD','104_1b1_Al_sc_Litt3200.wav')
Healthy_File = os.path.join('Data','Archive_2','Healthy','102_1b1_Ar_sc_Meditron.wav')
LRTI_File = os.path.join('Data','Archive_2','LRTI','108_1b1_Al_sc_Meditron.wav')
Pneumonia_File = os.path.join('Data','Archive_2','Pneumonia','122_2b1_Al_mc_LittC2SE.wav')
URTI_File = os.path.join('Data','Archive_2','URTI','101_1b1_Al_sc_Meditron.wav')

# %%
def load_wav(filename):
    # Load wav file
    file_contents = tf.io.read_file(filename)
    # Decode wav (tensors by channel)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    # Removes trailing axis
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    # Goes from 44100Hz to 16000Hz - amp of audio signal
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %%
asth_wave = load_wav(Asthma_File)
bronchsis_wave = load_wav(Bronchiectasis_File)
bronchtis_wave = load_wav(Bronchiolitis_File)
COPD_wave = load_wav(COPD_File)
health_wave = load_wav(Healthy_File)
LRTI_wave = load_wav(LRTI_File)
Pneu_wave = load_wav(Pneumonia_File)
URTI_wave = load_wav(URTI_File)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x000001F1655C7A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x000001F1655C7940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
plt.plot(Pneu_wave)
plt.plot(asth_wave)
# plt.plot(bronchsis_wave)
# plt.plot(bronchtis_wave)
# plt.plot(COPD_wave)
# plt.plot(health_wave)
# plt.plot(LRTI_wave)
# plt.plot(URTI_wave)
plt.show()

# %% [markdown]
# Wave to Spectrogram!

# %%
# Defining paths (again)!
Asthma = os.path.join('Data','Archive_2','Asthma')
Bronchiectasis = os.path.join('Data','Archive_2','Bronchiectasis')
Bronchiolitis = os.path.join('Data','Archive_2','Bronchiolitis')
COPD = os.path.join('Data','Archive_2','COPD')
Healthy = os.path.join('Data','Archive_2','Healthy')
LRTI = os.path.join('Data','Archive_2','LRTI')
Pneumonia = os.path.join('Data','Archive_2','Pneumonia')
URTI = os.path.join('Data','Archive_2','URTI')

# %%
# Tensorflow Dataset
# Looks for any wav files in each directory
AsthmaTFDS = tf.data.Dataset.list_files(Asthma+'\*.wav')
BronchiectasisTFDS = tf.data.Dataset.list_files(Bronchiectasis+'\*.wav')
BronchiolitisTFDS = tf.data.Dataset.list_files(Bronchiolitis+'\*.wav')
COPDTFDS = tf.data.Dataset.list_files(COPD+'\*.wav')
HealthyTFDS = tf.data.Dataset.list_files(Healthy+'\*.wav')
LRTITFDS = tf.data.Dataset.list_files(LRTI+'\*.wav')
PneumoniaTFDS = tf.data.Dataset.list_files(Pneumonia+'\*.wav')
URTITFDS = tf.data.Dataset.list_files(URTI+'\*.wav')

# %%
Asthma_Samples = tf.data.Dataset.zip((AsthmaTFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(AsthmaTFDS), 'Asthma'))))

Bronchiectasis_Samples = tf.data.Dataset.zip((BronchiectasisTFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(BronchiectasisTFDS), 'Bronchiectasis'))))

Bronchiolitis_Samples = tf.data.Dataset.zip((BronchiolitisTFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(BronchiolitisTFDS), 'Bronchiolitis'))))

COPD_Samples = tf.data.Dataset.zip((COPDTFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(COPDTFDS), 'COPD'))))

Healthy_Samples = tf.data.Dataset.zip((HealthyTFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(HealthyTFDS), 'Healthy'))))

LRTI_Samples = tf.data.Dataset.zip((LRTITFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(LRTITFDS), 'LRTI'))))

Pneumonia_Samples = tf.data.Dataset.zip((PneumoniaTFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(PneumoniaTFDS), 'Pneumonia'))))

URTI_Samples = tf.data.Dataset.zip((URTITFDS, tf.data.Dataset.from_tensor_slices(tf.fill(len(URTITFDS), 'URTI'))))

all_data = []
print(len(all_data))
all_data = Asthma_Samples.concatenate(Bronchiectasis_Samples)
print(len(all_data))
all_data = all_data.concatenate(Bronchiolitis_Samples)
print(len(all_data))
all_data = all_data.concatenate(COPD_Samples)
print(len(all_data))
all_data = all_data.concatenate(Healthy_Samples)
print(len(all_data))
all_data = all_data.concatenate(LRTI_Samples)
print(len(all_data))
all_data = all_data.concatenate(Pneumonia_Samples)
print(len(all_data))
all_data = all_data.concatenate(URTI_Samples)
print(len(all_data))
# Out:
# 0
# 34
# 60
# 1646
# 1716
# 1720
# 1794
# 1840

# %%
data_iterator = all_data.shuffle(500).as_numpy_iterator()
for item in all_data:
    print(data_iterator.next())
# Out:
# (b'Data\\Archive_2\\COPD\\130_3p4_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_2b2_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\156_8b3_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\213_1p2_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\211_1p2_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\116_1b2_Pl_sc_Meditron.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\200_2p4_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\139_1b1_Pl_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\213_2p2_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3p3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p3_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_1p3_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiolitis\\216_1b1_Pl_sc_Meditron.wav', b'Bronchiolitis')
# (b'Data\\Archive_2\\COPD\\151_2p3_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\201_1b3_Ar_sc_Meditron.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\Bronchiectasis\\201_1b3_Al_sc_Meditron.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\107_2b4_Ll_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiolitis\\149_1b1_Pl_sc_Meditron.wav', b'Bronchiolitis')
# (b'Data\\Archive_2\\COPD\\181_1b3_Tc_mc_LittC2SE_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b3_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_4b4_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\198_6p1_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b4_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\156_2b3_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b4_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_3p2_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\192_2b3_Ar_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_2b3_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\155_2b1_Al_mc_LittC2SE_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\176_2b3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\163_2b2_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\118_1b1_Pr_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_3b3_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\196_1b1_Pr_sc_Meditron.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\160_1b2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p2_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\207_3b2_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\174_1p4_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3p2_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\141_1b3_Al_mc_LittC2SE_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b4_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_2p2_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\162_1b2_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\163_2b2_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b3_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\113_1b1_Al_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\169_1b1_Lr_sc_Meditron.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\138_1p4_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\147_2b2_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\175_1b1_Pr_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\213_1p5_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\146_8p3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\170_1b3_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3p3_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p2_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\145_2b2_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p3_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_2b2_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_1p2_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\124_1b1_Pr_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\176_1b3_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\124_1b1_Pl_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b4_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\174_1p3_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\199_2b3_Ll_mc_LittC2SE_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p4_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b4_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\203_2p3_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_3b3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\180_1b4_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\193_7b3_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b5_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\205_4b2_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\201_1b1_Al_sc_Meditron_1.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\162_1b2_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_2b4_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\193_1b2_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\170_1b2_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\124_1b1_Al_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\104_1b1_Ll_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\170_1b3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\200_2p2_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\185_1b1_Al_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b4_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_1p4_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\189_1b2_Lr_mc_LittC2SE_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\205_3b4_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_1p2_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\221_2b3_Pr_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\223_1b1_Al_sc_Meditron.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\174_1p4_Ll_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\106_2b1_Pl_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\198_6p1_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\207_2b2_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\174_1p3_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiolitis\\167_1b1_Pr_sc_Meditron_1.wav', b'Bronchiolitis')
# (b'Data\\Archive_2\\COPD\\178_1b3_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\162_2b4_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\177_2b4_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\201_1b1_Ar_sc_Meditron_1.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\186_2b3_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\147_2b3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_2b2_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\158_1p2_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Asthma\\103_2b2_Ar_mc_LittC2SE_1.wav', b'Asthma')
# (b'Data\\Archive_2\\COPD\\130_1p4_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p3_Ll_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\200_2p3_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3b4_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\162_1b2_Ll_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\192_2b2_Ar_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b3_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b2_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\157_1b1_Pr_sc_Meditron.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_3p2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b3_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\218_1p1_Ar_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3b4_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\201_1b3_Ar_sc_Meditron_1.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\139_1b1_Pr_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\199_2b1_Ll_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\205_4b2_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b4_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiolitis\\149_1b1_Al_sc_Meditron_1.wav', b'Bronchiolitis')
# (b'Data\\Archive_2\\COPD\\130_1p2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\223_1b1_Ll_sc_Meditron_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\180_1b4_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_1p2_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\146_2b4_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\193_7b3_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\213_1p2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\198_1b5_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\193_7b3_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\193_7b3_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_2b5_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\212_2b2_Tc_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\218_1b1_Pr_sc_Meditron_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\146_8p3_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b4_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3p3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\205_4b2_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\158_1p4_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\176_1b3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_2b3_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\203_1p2_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b2_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_2b3_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\215_1b2_Ar_sc_Meditron_1.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\113_1b1_Pr_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\170_1b4_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\178_1b3_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_2p2_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\132_2b2_Lr_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\175_1b1_Pr_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\207_2b2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\213_2p2_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_1p4_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\166_1p1_Pr_sc_Meditron.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_2p2_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\177_1b2_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_1b3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_1p3_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_1b3_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\120_1b1_Pr_sc_Meditron.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\109_1b1_Ar_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_2b4_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b5_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\156_2b3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiolitis\\149_1b1_Pl_sc_Meditron_1.wav', b'Bronchiolitis')
# (b'Data\\Archive_2\\COPD\\174_1p2_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\178_1b6_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b5_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_2b5_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_2b2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3p2_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b5_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\176_1b4_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_1p4_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_2b2_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\147_1b2_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\113_1b1_Lr_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\133_2p2_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\120_1b1_Ar_sc_Meditron.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p3_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiolitis\\161_1b1_Al_sc_Meditron.wav', b'Bronchiolitis')
# (b'Data\\Archive_2\\COPD\\186_2b2_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\109_1b1_Pl_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\181_1b2_Ar_mc_LittC2SE.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\186_3b3_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\168_1b1_Al_sc_Meditron_1.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\172_1b3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\193_1b2_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b4_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\177_1b4_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_2p4_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\Bronchiectasis\\215_1b3_Tc_sc_Meditron_1.wav', b'Bronchiectasis')
# (b'Data\\Archive_2\\COPD\\130_2p5_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\172_1b3_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\205_3b4_Pl_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\170_2b2_Ar_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\175_1b1_Al_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\170_1b3_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\178_1b2_Ar_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\118_1b1_Al_sc_Litt3200.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_1b3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3p2_Pr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\192_2b1_Ar_mc_LittC2SE_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\110_1p1_Ll_sc_Meditron.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\158_1p4_Lr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\151_3p2_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_2b4_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\154_4b4_Lr_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\162_1b2_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_2b4_Al_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\146_8p3_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\138_1p4_Pr_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\107_2b3_Pl_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\160_1b3_Tc_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_2b2_Tc_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\104_1b1_Pr_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\133_2p3_Al_mc_AKGC417L_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\139_1b1_Lr_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\104_1b1_Ll_sc_Litt3200_1.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\\130_3b3_Ll_mc_AKGC417L.wav', b'COPD')
# (b'Data\\Archive_2\\COPD\
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram, label

# %%
filepath, label = Healthy_Samples.shuffle(buffer_size=10000).as_numpy_iterator().next()

# %%
spectrogram, label = preprocess(filepath, label)

# %%
spectrogram
# Out:
# <tf.Tensor: shape=(9991, 257, 1), dtype=float32, numpy=
# array([[[7.07332897e+00],
#         [5.97606421e+00],
#         [4.20810127e+00],
#         ...,
#         [2.45517935e-03],
#         [2.79931165e-03],
#         [3.85022163e-03]],
#
#        [[8.24134445e+00],
#         [7.01374054e+00],
#         [4.73589039e+00],
#         ...,
#         [2.24849302e-03],
#         [2.35495111e-03],
#         [4.14419174e-03]],
#
#        [[9.51979828e+00],
#         [7.46287489e+00],
#         [3.39479923e+00],
#         ...,
#         [2.28190911e-03],
#         [3.53827700e-03],
#         [1.48820877e-03]],
#
#        ...,
#
#        [[1.09601078e+01],
#         [1.03655500e+01],
#         [9.09556198e+00],
#         ...,
#         [8.02064408e-03],
#         [2.20605312e-03],
#         [4.64916229e-04]],
#
#        [[1.06985035e+01],
#         [9.89075756e+00],
#         [8.31816483e+00],
#         ...,
#         [8.85483529e-03],
#         [2.72955396e-03],
#         [6.70909882e-04]],
#
#        [[8.79083061e+00],
#         [7.85121584e+00],
#         [6.05201578e+00],
#         ...,
#         [7.43375299e-03],
#         [3.88867431e-03],
#         [8.11100006e-04]]], dtype=float32)>

# %%
plt.figure(figsize=(20,30))
plt.imshow(tf.transpose(spectrogram)[0])
plt.show()

# %% [markdown]
# Training and Testing Partitions!

# %%
# Tensorflow Data Pipeline
all_data = all_data.map(preprocess)
all_data = all_data.cache()
all_data = all_data.shuffle(buffer_size=1000)
all_data = all_data.batch(16)
all_data = all_data.prefetch(8)
# Out:
# WARNING:tensorflow:From C:\Users\jasmi\anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.

# %%
len(all_data)
# Out:
# 115

# %%
# Testing and Training Partitions
train = all_data.take(92) #80%
test = all_data.skip(92).take(23) #20%

# %%
samples, labels = train.as_numpy_iterator().next()

# %%
samples.shape
# Out:
# (16, 9991, 257, 1)

# %%
labels
# Out:
# array([b'COPD', b'COPD', b'COPD', b'COPD', b'COPD', b'COPD', b'COPD',
#        b'COPD', b'COPD', b'COPD', b'COPD', b'COPD', b'COPD', b'COPD',
#        b'COPD', b'COPD'], dtype=object)

# %% [markdown]
# Building the model!!

# %%
# Import dependencies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(9991, 257,1)))
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11628/3438971661.py in <module>
#       3 model.add(Conv2D(16, (3,3), activation='relu'))
#       4 model.add(Flatten())
# ----> 5 model.add(Dense(128, activation='relu'))
#       6 model.add(Dense(1, activation='sigmoid'))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py in _method_wrapper(self, *args, **kwargs)
#     203     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204     try:
# --> 205       result = method(self, *args, **kwargs)
#     206     finally:
#     207       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\backend.py in random_uniform(self, shape, minval, maxval, dtype, nonce)
#    2098             if nonce:
#    2099                 seed = tf.random.experimental.stateless_fold_in(seed, nonce)
# -> 2100             return tf.random.stateless_uniform(
#    2101                 shape=shape,
#    2102                 minval=minval,
#
# ResourceExhaustedError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:CPU:0}} OOM when allocating tensor with shape[40427376,128] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu [Op:Mul]
